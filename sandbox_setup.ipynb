# %%
import csv
import re

# %%
with open('H1B_FY_2015.csv') as f:
    lines = list(csv.reader(f, delimiter=';'))

# %%
lines[0]
# Out:
# ['',
#  'CASE_NUMBER',
#  'CASE_STATUS',
#  'CASE_SUBMITTED',
#  'DECISION_DATE',
#  'VISA_CLASS',
#  'EMPLOYMENT_START_DATE',
#  'EMPLOYMENT_END_DATE',
#  'EMPLOYER_NAME',
#  'EMPLOYER_ADDRESS1',
#  'EMPLOYER_ADDRESS2',
#  'EMPLOYER_CITY',
#  'EMPLOYER_STATE',
#  'EMPLOYER_POSTAL_CODE',
#  'EMPLOYER_COUNTRY',
#  'EMPLOYER_PROVINCE',
#  'EMPLOYER_PHONE',
#  'EMPLOYER_PHONE_EXT',
#  'AGENT_ATTORNEY_NAME',
#  'AGENT_ATTORNEY_CITY',
#  'AGENT_ATTORNEY_STATE',
#  'JOB_TITLE',
#  'SOC_CODE',
#  'SOC_NAME',
#  'NAIC_CODE',
#  'TOTAL WORKERS',
#  'FULL_TIME_POSITION',
#  'PREVAILING_WAGE',
#  'PW_UNIT_OF_PAY',
#  'PW_WAGE_LEVEL',
#  'PW_WAGE_SOURCE',
#  'PW_WAGE_SOURCE_YEAR',
#  'PW_WAGE_SOURCE_OTHER',
#  'WAGE_RATE_OF_PAY',
#  'WAGE_UNIT_OF_PAY',
#  'H-1B_DEPENDENT',
#  'WILLFUL VIOLATOR',
#  'WORKSITE_CITY',
#  'WORKSITE_COUNTY',
#  'WORKSITE_STATE',
#  'WORKSITE_POSTAL_CODE']

# %%
def header_index(arg, header):
    for i, ele in enumerate(header):
        if re.match(arg, ele):
            return i
    raise NameError('column not found')

def populate_indices(header):
    indices = {}
    indices['status'] = header_index('.*STATUS.*', header)
    indices['soc'] = header_index('.*SOC_CODE.*', header)
    indices['job_name'] = header_index('.*SOC_NAME.*', header)
    indices['job_state'] = header_index('.*EMPLOYER_STATE.*', header)
    return indices

# %%
indices = populate_indices(lines[0])
indices
# Out:
# {'status': 2, 'soc': 22, 'job_name': 23, 'job_state': 12}

# %%
def check_soc_hyphen(soc):
    if len(soc) < 6:
        return soc
    soc_lst = list(soc)
    
    if soc_lst[2] != '-':
        if soc_lst[2] == '.':
            soc_lst[2] = '-'
        else:
            soc_lst.insert(2, '-')
    return ''.join(soc_lst)

def clean_soc(soc):
    soc_strip = soc.replace(' ', '')
    soc_hyphen = check_soc_hyphen(soc_strip)
    return soc_hyphen[:7]

# %%
occupation_dict = {}
occupation_count = {}
state_count = {}
certified_count = 0

for line in lines[1:]:
    if line[indices['status']] != 'CERTIFIED':
        continue    
    
    soc = clean_soc(line[indices['soc']])  
    job_name = line[indices['job_name']]
    job_state = line[indices['job_state']]
    if not re.match('\d{2}-\d{4}', soc) or not job_state:
        continue
        
    certified_count += 1
    
    if soc not in occupation_dict:
        occupation_dict[soc] = job_name
        occupation_count[soc] = 0
    elif len(job_name) > len(occupation_dict[soc]):
        occupation_dict[soc] = job_name
    occupation_count[soc] += 1
    
    state = line[indices['job_state']]
    if state not in state_count:
        state_count[state] = 0
    state_count[state] += 1

# %%
occupation_dict
# Out:
# {'25-1032': 'ENGINEERING TEACHERS, POSTSECONDARY',
#  '17-2072': 'ELECTRONICS ENGINEERS, EXCEPT COMPUTER',
#  '15-1131': 'SOFTWARE DEVELOPERS, APPLICATIONS',
#  '15-1132': 'COMPUTER SOFTWARE ENGINEERS, APPLICATIONS',
#  '15-2031': 'OPERATIONS RESEARCH CONSULTANTS',
#  '15-1121': 'COMPUTER SOFTWARE ENGINEERS, APPLICATIONS',
#  '15-1199': 'COMPUTER OCCUPATIONS, ALL OTHER: INFORMATION TECHN',
#  '15-1141': 'DATABASE ADMINISTRATORS',
#  '27-4032': 'FILM AND VIDEO EDITORS',
#  '13-2051': 'FINANCIAL ANALYSTS',
#  '17-2081': 'WATER/WASTEWATER ENGINEERS',
#  '27-3031': 'PUBLIC RELATIONS SPECIALISTS',
#  '15-2041': 'CLINICAL DATA MANAGERS',
#  '17-2141': 'MECHANICAL ENGINEERING',
#  '15-1142': 'NETWORK AND COMPUTER SYSTEMS ADMINISTRATORS*',
#  '17-2021': 'AGRICULTURAL ENGINEERS',
#  '13-2011': 'OPERATIONS RESEARCH ANALYSTS',
#  '17-2171': 'PETROLEUM ENGINEERS',
#  '19-2032': 'MATERIALS SCIENTISTS',
#  '17-1011': 'ARCHITECTS, EXCEPT LANDSCAPE AND NAVAL',
#  '15-1134': 'WEB DEVELOPERS',
#  '13-1161': 'MARKET RESEARCH ANALYSTS AND MARKETING SPECIALISTS',
#  '15-1021': 'COMPUTER PROGRAMMERS',
#  '27-1024': 'GRAPHIC DESIGNERS',
#  '19-4041': 'GEOLOGICAL AND PETROLEUM TECHNICIANS',
#  '19-1013': 'SOIL AND PLANT SCIENTISTS',
#  '17-2041': 'MECHANICAL ENGINEERS',
#  '11-3071': 'TRANSPORTATION, STORAGE, AND DISTRIBUTION MANAGERS',
#  '15-1143': 'TELECOMMUNICATIONS ENGINEERING SPECIALISTS',
#  '19-2031': 'CHEMISTS',
#  '21-1015': 'REHABILITATION COUNSELORS',
#  '25-1021': 'COMPUTER SCIENCE TEACHERS, POSTSECONDARY',
#  '11-9199': 'REGULATORY AFFAIRS MANAGERS',
#  '17-2071': 'ELECTRICAL ENGINEERINGS',
#  '27-1025': 'INTERIOR DESIGNERS',
#  '29-1128': 'EXERCISE PHYSIOLOGISTS',
#  '25-1031': 'ARCHITECTURE TEACHERS, POSTSECONDARY',
#  '13-2099': 'FRAUD EXAMINERS, INVESTIGATORS AND ANALYSTS',
#  '29-1123': 'PHYSICAL THERAPISTS',
#  '11-3021': 'COMPUTER AND INFORMATIONS SYSTEMS MANAGERS',
#  '13-1081': 'LOGISTICS ENGINEERS',
#  '25-3099': 'TEACHERS AND INSTRUCTORS, ALL OTHER',
#  '19-4061': 'SOCIAL SCIENCE RESEARCH ASSISTANTS',
#  '25-1071': 'HEALTH SPECIALITIES TEACHERS, POSTSECONDARY',
#  '25-9031': 'INSTRUCTIONAL DESIGNERS AND TECHNOLOGISTS',
#  '15-1133': 'SOFTWARE DEVELOPPERS, SYSTEMS SOFTWARE',
#  '11-1011': 'FINANCIAL MANAGERS',
#  '17-2121': 'MARINE ENGINEERS AND NAVAL ARCHITECTS',
#  '17-2011': 'AEROSPACE ENGINEERS',
#  '25-2021': 'ELEMENTARY SCHOOL TEACHERS, EXCEPT SPECIAL EDUCATI',
#  '25-4012': 'CURATORS',
#  '15-1034': 'COMPUTER SOFTWARE ENGINEERS, APPLICATIONS NON R&AM',
#  '13-1111': 'MANAGEMENT ANALYSTS',
#  '11-2021': 'MARKETING MANAGERS',
#  '17-2112': 'HUMAN FACTORS ENGINEERS AND ERGONOMISTS',
#  '23-1011': 'ATTORNEY',
#  '29-1069': 'PHYSICIANS AND SURGEONS, ALL OTHERS',
#  '17-2131': 'MATERIALS ENGINEERS',
#  '29-1021': 'DENTISTS, GENERAL',
#  '25-2022': 'MIDDLE SCHOOL TEACHERS, EXCEPT SPECIAL AND CAREER/',
#  '27-1014': 'MULTIMEDIA ARTISTS AND ANIMATORS',
#  '43-3031': 'BOOKKEEPING, ACCOUNTING, AND AUDITING CLERKS',
#  '29-1031': 'DIETITIANS AND NUTRITIONISTS',
#  '17-3011': 'ARCHITECTURAL AND CIVIL DRAFTERS',
#  '11-1021': 'GENERAL AND OPERATIONS MANAGERS',
#  '11-9013': 'FARMERS, RANCHERS, AND OTHER AGRICULTURAL MANAGERS',
#  '13-1051': 'COST ESTIMATORS',
#  '17-2199': 'SOLAR ENERGY SYSTEMS ENGINEERS',
#  '13-2041': 'FINANCIAL SPECIALISTS, ALL OTHER',
#  '11-9121': 'CLINICAL RESEARCH COORDINATORS',
#  '25-1193': 'RECREATION AND FITNESS STUDIES TEACHERS, POSTSECON',
#  '25-1081': 'EDUCATION TEACHERS, POSTSECONDARY',
#  '29-1029': 'DENTISTS, ALL OTHER SPECIALISTS',
#  '15-1054': 'COMPUTER NETWORK ARCHITECTS, NON R&D',
#  '41-3099': 'SALES REPRESENTATIVES, SERVICES, ALL OTHER',
#  '17-2051': 'TRANSPORTATION ENGINEERS',
#  '15-1052': 'COMPUTER SYSTEMS ANALYSTS, NON R&D',
#  '17-1012': 'LANDSCAPE ARCHITECTS',
#  '19-1029': 'MOLECULAR AND CELLULAR BIOLOGISTS',
#  '19-3011': 'ECONOMISTS',
#  '29-1061': 'ANESTHESIOLOGISTS',
#  '19-2011': 'ASTRONOMERS',
#  '19-1042': 'MEDICAL SCIENTISTS, EXCEPT EPIDEMIOLOGISTS',
#  '17-3023': 'ELECTRICAL AND ELECTRONICS ENGINEERING TECHNICIANS',
#  '15-1122': 'INFORMATION SECURITY ANALYSTS',
#  '41-9031': 'SALES ENGINEERS',
#  '29-1171': 'NURSE PRACTITIONERS',
#  '29-1062': 'FAMILY AND GENERAL PRACTITIONERS',
#  '11-2031': 'PUBLIC RELATIONS AND FUNDRAISING MANAGERS',
#  '19-4021': 'BIOLOGICAL TECHNICIANS',
#  '11-9041': 'ARCHITECTURAL AND ENGINEERING MANAGERS',
#  '29-1063': 'PHYSICIANS AND SURGEONS, ALL OTHER',
#  '19-1021': 'BIOCHEMISTS AND BIOPHYSICISTS',
#  '17-2061': 'COMPUTER HARDWARE ENGINEERS',
#  '25-1125': 'HISTORY TEACHERS, POSTSECONDARY',
#  '19-1022': 'MICROBIOLOGISTS',
#  '29-2011': 'MEDICAL AND CLINICAL LABORATORY  TECHNOLOGISTS',
#  '15-1111': 'COMPUTER AND INFORMATION RESEARCH SCIENTISTS',
#  '25-1123': 'ENGLISH LANGUAGE AND LITERATURE TEACHERS, POSTSECO',
#  '11-3121': 'HUMAN RESOURCES MANAGERS',
#  '19-3051': 'URBAN AND REGIONAL PLANNERS',
#  '19-2012': 'PHYSICISTS',
#  '11-3051': 'QUALITY CONTROL SYSTEMS MANAGERS',
#  '27-3041': 'EDITORS',
#  '19-4011': 'AGRICULTURAL AND FOOD SCIENCE TECHNICIANS',
#  '29-1122': 'OCCUPATIONAL THERAPISTS',
#  '27-1021': 'MECHANICAL ENGINEER / PROGRAM MANAGER',
#  '25-2052': 'SPECIAL EDUCATION TEACHERS, KINDERGARTEN AND ELEME',
#  '11-9081': 'LODGING MANAGERS',
#  '15-1022': 'COMPUTER PROGRAMMERS, NON R & D',
#  '25-2012': 'KINDERGARTEN TEACHERS, EXCEPT SPECIAL EDUCATION',
#  '17-1022': 'SURVEYORS',
#  '11-2022': 'SALES MANAGERS',
#  '17-3029': 'ENGINEERING TECHNICIANS, EXCEPT DRAFTERS, ALL OTHE',
#  '27-3091': 'INTERPRETERS AND TRANSLATORS',
#  '17-2031': 'BIOMEDICAL ENGINEERS',
#  '15-1035': 'COMPUTER SOFTWARE ENGINEERS, APPLICATIONS, R&D',
#  '19-1012': 'FOOD SCIENTISTS AND TECHNOLOGISTS',
#  '17-3031': 'SURVEYING AND MAPPING TECHNICIANS',
#  '23-2099': 'LEGAL SUPPORT WORKERS, ALL OTHER',
#  '25-1124': 'FOREIGN LANGUAGE AND LITERATURE TEACHERS, POST SEC',
#  '25-2031': 'SECONDARY SCHOOL TEACHERS, EXCEPT SPECIAL AND CAREER/TECHNICAL EDUCATION',
#  '29-9091': 'ATHLETIC TRAINERS',
#  '25-4021': 'LIBRARIANS',
#  '13-1151': 'TRAINING AND DEVELOPMENT SPECIALISTS',
#  '11-3031': 'TREASURERS, CONTROLLERS, AND CHIEF FINANCIAL OFFIC',
#  '13-1199': 'BUSINESS OPERATIONS SPECIALISTS, ALL OTHER*',
#  '17-3013': 'MECHANICAL DRAFTERS',
#  '15-1152': 'COMPUTER NETWORK SUPPORT SPECIALISTS',
#  '29-1141': 'REGISTERED NURSES',
#  '15-2011': 'ACTUARIES',
#  '29-1065': 'PEDIATRICIANS, GENERAL',
#  '25-1063': 'ECONOMICS TEACHERS, POSTSECONDARY',
#  '29-1066': 'PSYCHIATRISTS',
#  '29-1067': 'SURGEONS',
#  '21-1021': 'CHILD, FAMILY, AND SCHOOL SOCIAL WORKERS',
#  '21-2011': 'CLERGY',
#  '11-3131': 'TRAINING AND DEVELOPMENT MANAGERS',
#  '43-4161': 'HUMAN RESOURCES ASSISTANTS, EXCEPT PAYROLL AND',
#  '13-2031': 'BUDGET ANALYSTS',
#  '13-1071': 'HUMAN RESOURCES SPECIALISTS',
#  '11-3011': 'ADMINISTRATIVE SERVICES MANAGERS',
#  '29-1199': 'HEALTH DIAGNOSING AND TREATING PRACTITIONERS, ALL',
#  '13-1141': 'COMPENSATION, BENEFITS, AND JOB ANALYSIS SPECIALIS',
#  '27-1011': 'ART DIRECTORS',
#  '11-3061': 'PURCHASING MANAGERS',
#  '15-1151': 'COMPUTER USER SUPPORT SPECIALISTS',
#  '15-1037': 'SOFTWARE DEVELOPERS, SYSTEMS SOFTWARE, R&D (ACWIA',
#  '25-1022': 'MATHEMATICAL SCIENCE TEACHERS, POSTSECONDARY',
#  '29-9011': 'OCCUPATIONAL HEALTH AND SAFETY SPECIALISTS',
#  '15-1799': 'COMPUTER OCCUPATIONS, ALL OTHER*',
#  '19-1011': 'ANIMAL SCIENTISTS',
#  '25-9099': 'EDUCATION, TRAINING, AND LIBRARY WORKERS, ALL',
#  '25-1121': 'ART, DRAMA, AND MUSIC TEACHERS, POSTSECONDARY',
#  '53-2012': 'COMMERCIAL PILOTS',
#  '19-2042': 'GEOSCIENTISTS, EXCEPT HYDROLOGISTS AND GEOGRAPHERS',
#  '27-2012': 'DIRECTORS- STAGE, MOTION PICTURES, TELEVISION, AND',
#  '25-1072': 'NURSING INSTRUCTORS AND TEACHERS, POSTSECONDARY',
#  '27-3042': 'TECHNICAL WRITERS',
#  '11-9021': 'CONSTRUCTION MANAGERS',
#  '15-2099': 'MATHEMATICAL SCIENCE OCCUPATIONS, ALL OTHER',
#  '25-1052': 'CHEMISTRY TEACHERS, POSTSECONDARY',
#  '11-9033': 'EDUCATION ADMINISTRATORS, POSTSECONDARY',
#  '29-1131': 'VETERINARIANS',
#  '21-1011': 'SUBSTANCE ABUSE AND BEHAVIORAL DISORDER COUNSELORS',
#  '25-1011': 'BUSINESS TEACHERS, POSTSECONDARY',
#  '15-1053': 'COMPUTER SYSTEMS ANALYSTS, R&D',
#  '27-2022': 'COACHES AND SCOUTS',
#  '29-1051': 'PHARMACISTS',
#  '19-3094': 'POLITICAL SCIENTISTS',
#  '25-1042': 'BIOLOGICAL SCIENCE TEACHERS, POSTSECONDARY',
#  '21-2021': 'DIRECTORS, RELIGIOUS ACTIVITIES AND EDUCATION',
#  '19-3031': 'CLINICAL, COUNSELING, AND SCHOOL PSYCHOLOGISTS',
#  '25-3021': 'SELF-ENRICHMENT EDUCATION TEACHERS',
#  '21-1022': 'HEALTHCARE SOCIAL WORKERS',
#  '27-1022': 'FASHION DESIGNERS',
#  '17-3022': 'CIVIL ENGINEERING TECHNICIANS',
#  '11-9111': 'MEDICAL AND HEALTH SERVICES MANAGERS',
#  '21-1014': 'MENTAL HEALTH COUNSELORS',
#  '11-2011': 'ADVERTISING AND PROMORTIONS MANAGERS',
#  '41-4011': 'SALES REPRESENTATIVES, WHOLESALE AND MANUFACTURING',
#  '13-1121': 'MEETING, CONVENTION, AND EVENT PLANNERS*',
#  '19-2021': 'ATMOSPHERIC AND SPACE SCIENTISTS',
#  '29-1064': 'OBSTETRICIANS AND GYNECOLOGISTS',
#  '29-1127': 'SPEECH AND LANGUAGE PATHOLOGISTS',
#  '29-1071': 'PHYSICIAN ASSISTANTS',
#  '25-1054': 'PHYSICS TEACHERS, POSTSECONDARY',
#  '51-9071': 'JEWELERS AND PRECIOUS STONE AND METAL WORKERS',
#  '25-9041': 'TEACHER ASSISTANTS',
#  '19-3099': 'SOCIAL SCIENTISTS AND RELATED WORKERS, ALL OTHER',
#  '29-9099': 'HEALTHCARE PRACTITIONERS AND TECHNICAL WORKERS, AL',
#  '49-1011': 'FIRST-LINE SUPERVISORS OF MECHANICS, INSTALLERS, A',
#  '29-2012': 'MEDICAL AND CLINICAL LABORATORY TECHNICIANS',
#  '25-1041': 'AGRICULTURAL SCIENCES TEACHERS, POSTSECONDARY',
#  '13-1041': 'REGULATORY AFFAIRS SPECIALISTS',
#  '19-3091': 'ANTHROPOLOGISTS AND ARCHEOLOGISTS',
#  '19-3041': 'SOCIOLOGISTS',
#  '41-4012': 'SALES REPRESENTATIVES, WHOLESALE AND MANUFACTURING',
#  '25-2053': 'SPECIAL EDUCATION TEACHERS, MIDDLE SCHOOL',
#  '37-1011': 'FIRST-LINE SUPERVISORS OF HOUSEKEEPING AND',
#  '27-1019': 'ARTISTS AND RELATED WORKERS, ALL OTHER',
#  '15-2021': 'MATHEMATICIANS',
#  '25-3011': 'ADULT BASIC AND SECONDARY EDUCATION AND LITERACY T',
#  '17-2074': 'ELECTRICAL ENGINEERS, R&D',
#  '11-9151': 'SOCIAL AND COMMUNITY SERVICE MANAGERS',
#  '19-1041': 'EPIDEMIOLOGISTS',
#  '41-3031': 'SECURITIES, COMMODITIES, AND FINANCIAL SERVICES SA',
#  '19-2099': 'PHYSICAL SCIENTISTS, ALL OTHER',
#  '25-1122': 'COMMUNICATIONS TEACHERS, POSTSECONDARY',
#  '21-1091': 'HEALTH EDUCATORS',
#  '17-2053': 'CIVIL ENGINEERS, R&D',
#  '27-3099': 'MEDIA AND COMMUNICATION WORKERS, ALL OTHER',
#  '31-2021': 'PHYSICAL THERAPIST ASSISTANTS',
#  '17-2144': 'MECHANICAL ENGINEERS, R&D',
#  '25-1066': 'PSYCHOLOGY TEACHERS, POSTSECONDARY',
#  '19-1099': 'LIFE SCIENTISTS, ALL OTHER',
#  '13-1022': 'WHOLESALE AND RETAIL BUYERS, EXCEPT FARM PRODUCTS',
#  '27-3043': 'WRITERS AND AUTHORS',
#  '17-3012': 'ELECTRICAL AND ELECTRONICS DRAFTERS',
#  '15-1032': 'COMPUTER SOFTWARE ENGINEERS, SYSTEMS SOFTWARE',
#  '17-2161': 'NUCLEAR ENGINEERS',
#  '19-4099': 'LIFE, PHYSICAL, AND SOCIAL SCIENCE TECHNICIANS, AL',
#  '43-9111': 'BIOINFORMATICS TECHNICIANS',
#  '29-9092': 'GENETIC COUNSELORS',
#  '17-2076': 'ELECTRONICS ENGINEERS, EXCEPT COMPUTER, R&D',
#  '19-3092': 'GEOGRAPHERS',
#  '41-9012': 'MODELS',
#  '17-2073': 'ELECTRICAL ENGINEERS, NON R&D',
#  '19-2043': 'HYDROLOGISITS',
#  '25-1082': 'LIBRARY SCIENCE TEACHERS, POSTSECONDARY',
#  '25-2011': 'PRESCHOOL TEACHERS, EXCEPT SPECIAL EDUCATION',
#  '13-2052': 'PERSONAL FINANCIAL ADVISORS',
#  '15-1031': 'COMPUTER SOFTWARE ENGINEERS, APPLICATIONS',
#  '45-1011': 'FIRST LINE SUPERVISORS OF FARMING, FISHING, AND FO',
#  '49-9044': 'MILLWRIGHTS',
#  '21-1012': 'EDUCATIONAL, GUIDANCE, SCHOOL, AND VOCATIONAL COUN',
#  '25-1111': 'CRIMINAL JUSTICE AND LAW ENFORCEMENT TEACHERS, POS',
#  '15-1099': 'SOFTWARE QUALITY ASSURANCE ENGINEERS AND TESTERS',
#  '25-2054': 'SPECIAL EDUCATION TEACHERS, SECONDARY SCHOOL',
#  '13-1131': 'FUNDRAISERS',
#  '25-2041': 'SPECIAL EDUCATION TEACHERS, PRESCHOOL,',
#  '17-2111': 'HEALTH AND SAFETY ENGINEERS, EXCEPT MINING SAFETY',
#  '35-1011': 'CHEFS AND HEAD COOKS',
#  '17-2075': 'ELECTRONICS ENGINEERS, EXCEPT COMPUTER, NON',
#  '23-2011': 'PARALEGALS AND LEGAL ASSISTANTS*',
#  '19-2041': 'ENVIRONMENTAL SCIENTISTS AND SPECIALISTS, INCLUDIN',
#  '25-1061': 'ANTHROPOLOGY AND ARCHEOLOGY TEACHERS, POSTSECONDAR',
#  '29-2091': 'ORTHOTISTS AND PROSTHETISTS',
#  '25-1199': 'POST SECONDARY TEACHERS, ALL OTHER',
#  '31-9099': 'HEALTHCARE SUPPORT WORKERS, ALL OTHER',
#  '19-3039': 'PSYCHOLOGISTS, ALL OTHER',
#  '17-1021': 'CARTOGRAPHERS AND PHOTOGRAMMETRISTS',
#  '25-2059': 'SPECIAL EDUCATION TEACHERS, ALL OTHER',
#  '13-1011': 'AGENTS AND BUSINESS MANAGERS OF ARTISTS,',
#  '29-1081': 'PODIATRISTS',
#  '17-2052': 'CIVIL ENGINEERS, NON R&D',
#  '11-9032': 'EDUCATION ADMINISTRATORS, ELEMENTARY AND SECONDARY',
#  '15-1150': 'COMPUTER SUPPORT SPECIALISTS',
#  '19-3022': 'SURVEY RESEARCHERS',
#  '17-3027': 'MECHANICAL ENGINEERING TECHNICIANS',
#  '25-1053': 'ENVIRONMENTAL SCIENCE TEACHERS, POSTSECONDARY',
#  '25-1065': 'POLITICAL SCIENCE TEACHERS, POSTSECONDARY',
#  '25-1043': 'FORESTRY AND CONSERVATION SCIENCE TEACHERS,',
#  '17-2151': 'MINING AND GEOLOGICAL ENGINEERS, INCLUDING MINING',
#  '29-1041': 'OPTOMETRISTS',
#  '41-3011': 'ADVERTISING SALES AGENTS',
#  '25-1113': 'SOCIAL WORK TEACHERS, POSTSECONDARY',
#  '15-1051': 'COMPUTER SYSTEMS ANALYSTS',
#  '51-3092': 'FOOD BATCHMAKERS',
#  '25-1051': 'ATMOSPHERIC, EARTH, MARINE, AND SPACE SCIENCES TEA',
#  '29-1022': 'ORAL AND MAXILLOFACIAL SURGEONS',
#  '43-6011': 'EXECUTIVE SECRETARIES AND EXECUTIVE ADMINISTRATIVE',
#  '43-6014': 'SECRETARIES AND ADMINISTRATIVE ASSISTANTS, EXCEPT',
#  '13-2061': 'OPERATIONS RESEARCH ANALYSTS',
#  '15-1036': 'SOFTWARE DEVELOPERS, SYSTEMS SOFTWARE, NON R&D',
#  '11-9161': 'EMERGENCY MANAGEMENT DIRECTORS',
#  '43-9041': 'INSURANCE CLAIMS AND POLICY PROCESSING CLERKS',
#  '43-9199': 'OFFICE AND ADMINISTRATIVE SUPPORT WORKERS, ALL',
#  '43-1011': 'FIRST-LINE SUPERVISORS OF OFFICE AND',
#  '39-9041': 'RESIDENTIAL ADVISORS',
#  '13-1023': 'PURCHASING AGENTS, EXCEPT WHOLESALE, RETAIL, AND F',
#  '15-2091': 'MATHEMATICAL TECHNICIANS',
#  '25-3999': 'TEACHERS AND INSTRUCTORS, ALL OTHER*',
#  '15-1311': 'COMPUTER PROGRAMMERS',
#  '23-1012': 'JUDICIAL LAW CLERKS',
#  '25-1126': 'PHILOSOPHY AND RELIGION TEACHERS, POSTSECONDARY',
#  '21-1099': 'COMMUNITY AND SOCIAL SERVICE SPECIALISTS, ALL OTHE',
#  '27-3022': 'REPORTERS AND CORRESPONDENTS',
#  '27-1027': 'SET AND EXHIBIT DESIGNERS',
#  '53-2011': 'AIRLINE PILOTS, COPILOTS, AND FLIGHT ENGINEERS',
#  '41-3021': 'INSURANCE SALES AGENTS',
#  '19-3032': 'INDUSTRIAL-ORGANIZATIONAL PSYCHOLOGISTS',
#  '15-1023': 'COMPUTER PROGRAMMERS R & D',
#  '21-1023': 'MENTAL HEALTH AND SUBSTANCE ABUSE SOCIAL WORKERS',
#  '19-1031': 'CONSERVATION SCIENTISTS',
#  '43-4051': 'CUSTOMER SERVICE REPRESENTATIVES',
#  '45-2021': 'ANIMAL BREEDERS',
#  '29-2052': 'PHARMACY TECHNICIANS',
#  '29-2031': 'CARDIOVASCULAR TECHNOLOGISTS AND TECHNICIANS',
#  '13-2071': 'CREDIT COUNSELORS',
#  '29-1111': 'REGISTERED NURSES*',
#  '13-2053': 'INSURANCE UNDERWRITERS',
#  '51-4032': 'DRILLING AND BORING MACHINE TOOL SETTERS,',
#  '29-2099': 'HEALTH TECHNOLOGISTS AND TECHNICIANS, ALL OTHER',
#  '17-2143': 'MECHANICAL ENGINEERS, NON R&D',
#  '53-6051': 'FREIGHT AND CARGO INSPECTORS',
#  '33-9021': 'PRIVATE DETECTIVES AND INVESTIGATORS',
#  '21-1019': 'COUNSELORS, ALL OTHER',
#  '25-1067': 'SOCIOLOGY TEACHERS, POSTSECONDARY',
#  '19-4031': 'BIOLOGICAL TECHNICIANS',
#  '25-9021': 'FARM AND HOME MANAGEMENT ADVISORS',
#  '25-1062': 'AREA, ETHNIC, AND CULTURAL STUDIES TEACHERS, POSTS',
#  '11-9141': 'PROPERTY, REAL ESTATE, AND COMMUNITY ASSOCIATION M',
#  '25-1112': 'LAW TEACHERS, POSTSECONDARY',
#  '29-1129': 'THERAPISTS, ALL OTHER',
#  '17-3021': 'AEROSPACE ENGINEERING AND OPERATIONS TECHNICIANS',
#  '11-9031': 'EDUCATION ADMINISTRATORS, PRESCHOOL AND CHILDCARE',
#  '15-1331': 'COMPUTER PROGRAMMERS',
#  '51-7041': 'SAWING MACHINE SETTERS, OPERATORS, AND TENDERS,',
#  '51-4121': 'WELDERS, CUTTERS, SOLDERERS, AND BRAZERS',
#  '43-5061': 'PRODUCTION, PLANNING, AND EXPEDITING CLERKS',
#  '47-4011': 'CONSTRUCTION AND BUILDING INSPECTORS',
#  '47-2141': 'PAINTERS, CONSTRUCTION AND MAINTENANCE',
#  '51-1011': 'FIRST-LINE SUPERVISORS OF PRODUCTION AND OPERATING',
#  '25-9011': 'AUDIO-VISUAL AND MULTIMEDIA COLLECTIONS',
#  '51-9122': 'PAINTERS, TRANSPORTATION EQUIPMENT',
#  '41-1012': 'FIRST-LINE SUPERVISORS OF NON-RETAIL SALES WORKERS',
#  '33-9099': 'PROTECTIVE SERVICE WORKERS, ALL OTHER',
#  '21-1029': 'SOCIAL WORKERS, ALL OTHERS',
#  '11-9051': 'FOOD SERVICE MANAGERS',
#  '27-1029': 'DESIGNERS, ALL OTHERS',
#  '31-9092': 'MEDICAL ASSISTANTS',
#  '29-1181': 'AUDIOLOGISTS',
#  '25-1192': 'HOME ECONOMICS TEACHERS, POSTSECONDARY',
#  '27-2099': 'ENTERTAINERS AND PERFORMERS, SPORTS AND RELATED',
#  '15-1191': 'COMPUTER OCCUPATIONS, ALL OTHER',
#  '31-9096': 'VETERINARY ASSISTANTS AND LABORATORY ANIMAL',
#  '25-4013': 'MUSEUM TECHNICIANS AND CONSERVATORS',
#  '17-3026': 'INDUSTRIAL ENGINEERING TECHNICIANS',
#  '39-9099': 'PERSONAL CARE AND SERVICE WORKERS, ALL OTHER',
#  '31-2022': 'PHYSICAL THERAPIST AIDES',
#  '21-1013': 'MARRIAGE AND FAMILY THERAPISTS',
#  '25-1194': 'VOCATIONAL EDUCATION TEACHERS, POSTSECONDARY',
#  '11-9039': 'EDUCATION ADMINISTRATORS, ALL OTHER',
#  '39-9031': 'FITNESS TRAINERS AND AEROBICS INSTRUCTORS',
#  '19-1023': 'ZOOLOGISTS AND WILDLIFE BIOLOGISTS',
#  '39-9032': 'RECREATION WORKERS',
#  '29-1023': 'ORTHODONTISTS',
#  '29-2092': 'HEARING AID SPECIALISTS',
#  '19-4091': 'ENVIRONMENTAL SCIENCE AND PROTECTION TECHNICIANS,',
#  '31-1014': 'NURSING ASSISTANTS',
#  '25-1069': 'SOCIAL SCIENCES TEACHERS, POSTSECONDARY, ALL OTHER',
#  '11-1531': 'COMPUTER PROGRAMMERS',
#  '19-3093': 'HISTORIANS',
#  '29-9199': 'HEALTH PROFESSIONALS AND TECHNICIANS, ALL OTHER',
#  '27-3021': 'BROADCAST NEWS ANALYSTS',
#  '39-3032': 'RECREATION WORKERS',
#  '25-2051': 'SPECIAL EDUCATION TEACHERS, PRESCHOOL',
#  '29-2032': 'DIAGNOSTIC MEDICAL SONOGRAPHERS',
#  '49-9021': 'HEATING, AIR CONDITIONING, AND REFRIGERATION',
#  '25-1064': 'GEOGRAPHY TEACHERS, POSTSECONDARY',
#  '39-9011': 'CHILDCARE WORKERS',
#  '49-9064': 'WATCH REPAIRERS',
#  '47-4099': 'CONSTRUCTION AND RELATED WORKERS, ALL OTHER',
#  '27-2041': 'MUSIC DIRECTORS AND COMPOSERS',
#  '11-3111': 'COMPENSATION AND BENEFITS MANAGERS',
#  '29-1011': 'CHIROPRACTORS',
#  '15-1061': 'DATABASE ADMINISTRATORS',
#  '21-1093': 'SOCIAL AND HUMAN SERVICE ASSISTANTS',
#  '49-2094': 'ELECTRICAL AND ELECTRONICS REPAIRERS, COMMERCIAL',
#  '15-1055': 'COMPUTER NETWORK ARCHITECTS, R&D',
#  '29-9799': 'HEALTHCARE PRACTITIONERS AND TECHNICAL WORKERS,',
#  '13-1031': 'CLAIMS ADJUSTERS, EXAMINERS, AND INVESTIGATORS',
#  '21-1094': 'COMMUNITY HEALTH WORKERS',
#  '29-2034': 'RADIOLOGIC TECHNOLOGISTS',
#  '43-3021': 'BILLING AND POSTING CLERKS',
#  '15-1071': 'NETWORK AND COMPUTER SYSTEMS ADMINISTRATORS',
#  '29-1024': 'PROSTHODONTISTS',
#  '29-2041': 'EMERGENCY MEDICAL TECHNICIANS AND PARAMEDICS',
#  '45-2092': 'FARMWORKERS AND LABORERS, CROP, NURSERY, AND',
#  '41-9022': 'REAL ESTATE SALES AGENTS',
#  '53-6099': 'TRANSPORTATION WORKERS, ALL OTHER',
#  '21-1798': 'COMMUNITY AND SOCIAL SERVICE SPECIALISTS, ALL',
#  '39-7012': 'TRAVEL GUIDES',
#  '29-2071': 'MEDICAL RECORDS AND HEALTH INFORMATION TECHNICIANS',
#  '27-4011': 'AUDIO AND VIDEO EQUIPMENT TECHNICIANS',
#  '13-2072': 'LOAN OFFICERS',
#  '41-1011': 'FIRST-LINE SUPERVISORS OF RETAIL SALES WORKERS',
#  '51-9081': 'DENTAL LABORATORY TECHNICIANS',
#  '27-2042': 'MUSICIANS AND SINGERS',
#  '29-1125': 'RECREATIONAL THERAPISTS',
#  '49-2095': 'ELECTRICAL AND ELECTRONICS REPAIRERS, POWERHOUSE,',
#  '29-1126': 'RESPIRATORY THERAPISTS',
#  '39-2011': 'ANIMAL TRAINERS',
#  '25-4011': 'ARCHIVISTS',
#  '41-9041': 'TELEMARKETERS',
#  '41-9099': 'SALES AND RELATED WORKERS, ALL OTHER',
#  '13-1021': 'BUYERS AND PURCHASING AGENTS, FARM PRODUCTS',
#  '17-3019': 'DRAFTERS, ALL OTHER',
#  '23-1022': 'ARBITRATORS, MEDIATORS, AND CONCILIATORS',
#  '13-2082': 'TAX PREPARERS',
#  '43-9011': 'COMPUTER OPERATORS',
#  '35-1012': 'FIRST-LINE SUPERVISORS OF FOOD PREPARATION AND SER',
#  '53-5021': 'CAPTAINS, MATES, AND PILOTS OF WATER VESSELS',
#  '43-5071': 'SHIPPING, RECEIVING, AND TRAFFIC CLERKS',
#  '21-1092': 'PROBATION OFFICERS AND CORRECTIONAL TREATMENT',
#  '47-2211': 'SHEET METAL WORKERS',
#  '33-3021': 'DETECTIVES AND CRIMINAL INVESTIGATORS',
#  '17-3024': 'ELECTRO-MECHANICAL TECHNICIANS',
#  '53-1031': 'FIRST-LINE SUPERVISORS OF TRANSPORTATION AND',
#  '13-2021': 'APPRAISERS AND ASSESSORS OF REAL ESTATE',
#  '47-2073': 'OPERATING ENGINEERS AND OTHER CONSTRUCTION',
#  '41-3041': 'TRAVEL AGENTS',
#  '17-3025': 'ENVIRONMENTAL ENGINEERING TECHNICIANS',
#  '25-9030': 'INSTRUCTIONAL COORDINATORS',
#  '19-1032': 'FORESTERS',
#  '45-2093': 'FARMWORKERS, FARM, RANCH, AND AQUACULTURAL ANIMALS',
#  '27-3011': 'RADIO AND TELEVISION ANNOUNCERS',
#  '29-2056': 'VETERINARY TECHNOLOGISTS AND TECHNICIANS',
#  '19-4092': 'FORENSIC SCIENCE TECHNICIANS',
#  '27-1013': 'FINE ARTISTS, INCLUDING PAINTERS, SCULPTORS, AND',
#  '15-1011': 'COMPUTER AND INFORMATION SCIENTISTS, RESEARCH',
#  '19-3021': 'MARKET RESEARCH ANALYSTS',
#  '25-2025': 'SPECIAL EDUCATION TEACHERS, KINDERGARTEN AND ELEME',
#  '43-3011': 'BILL AND ACCOUNT COLLECTORS',
#  '35-9099': 'FOOD PREPARATION AND SERVING RELATED WORKERS, ALL',
#  '51-3011': 'BAKERS',
#  '27-4021': 'PHOTOGRAPHERS',
#  '25-2023': 'CAREER/TECHNICAL EDUCATION TEACHERS, MIDDLE SCHOOL',
#  '37-1012': 'FIRST-LINE SUPERVISORS OF LANDSCAPING, LAWN',
#  '31-9095': 'PHARMACY AIDES',
#  '14-2051': 'TRANSPORTATION ENGINEERS',
#  '43-4011': 'BROKERAGE CLERKS',
#  '39-3031': 'USHERS, LOBBY ATTENDANTS, AND TICKET TAKERS',
#  '27-2014': 'MULTIMEDIA ARTISTS AND ANIMATORS',
#  '26-1067': 'PHYSICIANS AND SURGEONS, ALL OTHER',
#  '23-2093': 'TITLE EXAMINERS, ABSTRACTORS, AND SEARCHERS',
#  '47-1011': 'SUPERVISORS OF CONSTRUCTION AND EXTRACTION WORKERS',
#  '41-2011': 'CASHIERS',
#  '43-4041': 'CREDIT AUTHORIZERS, CHECKERS, AND CLERKS',
#  '25-2032': 'CAREER/TECHNICAL EDUCATION TEACHERS, SECONDARY',
#  '51-6099': 'TEXTILE, APPAREL, AND FURNISHINGS WORKERS, ALL',
#  '13-1078': 'HUMAN RESOURCES, TRAINING, AND LABOR RELATIONS',
#  '51-5112': 'PRINTING PRESS OPERATORS',
#  '15-2013': 'OPERATIONS RESEARCH ANALYSTS',
#  '49-3023': 'AUTOMOTIVE SERVICE TECHNICIANS AND MECHANICS',
#  '43-5032': 'DISPATCHERS, EXCEPT POLICE, FIRE, AND AMBULANCE',
#  '53-6041': 'TRAFFIC TECHNICIANS',
#  '51-6052': 'TAILORS, DRESSMAKERS, AND CUSTOM SEWERS',
#  '49-9062': 'MEDICAL EQUIPMENT REPAIRERS',
#  '21-2099': 'RELIGIOUS WORKERS, ALL OTHER',
#  '29-1151': 'NURSE ANESTHETISTS',
#  '43-3099': 'FINANCIAL CLERKS, ALL OTHER',
#  '15-1179': 'INFORMATION SECURITY ANALYSTS, WEB DEVELOPERS, AND',
#  '13-2081': 'TAX EXAMINERS AND COLLECTORS, AND REVENUE AGENTS',
#  '27-4031': 'CAMERA OPERATORS, TELEVISION, VIDEO, AND MOTION',
#  '43-3061': 'PROCUREMENT CLERKS',
#  '43-5011': 'CARGO AND FREIGHT AGENTS',
#  '13-1075': 'LABOR RELATIONS SPECIALISTS',
#  '43-4081': 'HOTEL, MOTEL, AND RESORT DESK CLERKS',
#  '31-1012': 'NURSING AIDES, ORDERLIES, AND ATTENDANTS',
#  '41-9021': 'REAL ESTATE BROKERS',
#  '17-2016': 'HARDWARE ENGINEERS',
#  '43-6012': 'LEGAL SECRETARIES',
#  '51-9061': 'INSPECTORS, TESTERS, SORTERS, SAMPLERS, AND',
#  '31-9091': 'DENTAL ASSISTANTS',
#  '17-2062': 'COMPUTER HARDWARE ENGINEERS, NON R&D',
#  '51-2023': 'ELECTROMECHANICAL EQUIPMENT ASSEMBLERS',
#  '27-4014': 'SOUND ENGINEERING TECHNICIANS',
#  '27-2032': 'CHOREOGRAPHERS',
#  '41-2031': 'RETAIL SALESPERSONS',
#  '39-3091': 'AMUSEMENT AND RECREATION ATTENDANTS',
#  '37-2012': 'MAIDS AND HOUSEKEEPING CLEANERS',
#  '35-2014': 'COOKS, RESTAURANT',
#  '27-2011': 'ACTORS',
#  '43-3051': 'PAYROLL AND TIMEKEEPING CLERKS',
#  '49-3011': 'AIRCRAFT MECHANICS AND SERVICE TECHNICIANS',
#  '13-1611': 'MARKET RESEARCH ANALYSTS AND MARKETING SPECIALISTS',
#  '35-3041': 'FOOD SERVERS, NONRESTAURANT',
#  '43-9061': 'OFFICE CLERKS, GENERAL',
#  '43-4151': 'ORDER CLERKS',
#  '19-4051': 'NUCLEAR TECHNICIANS',
#  '51-4122': 'WELDING, SOLDERING, AND BRAZING MACHINE SETTERS,',
#  '29-1124': 'RADIATION THERAPISTS',
#  '39-1011': 'GAMING SUPERVISORS',
#  '45-2099': 'AGRICULTURAL WORKERS, ALL OTHER',
#  '25-1191': 'GRADUATE TEACHING ASSISTANTS',
#  '51-4012': 'COMPUTER NUMERICALLY CONTROLLED MACHINE TOOL',
#  '29-2799': 'HEALTH TECHNOLOGISTS AND TECHNICIANS, ALL OTHER*',
#  '51-6092': 'FABRIC AND APPAREL PATTERNMAKERS',
#  '31-1011': 'HOME HEALTH AIDES',
#  '25-3098': 'SUBSTITUTE TEACHERS (OES ONLY)',
#  '19-1069': 'PHYSICIANS AND SURGEONS, ALL OTHER',
#  '27-4012': 'BROADCAST TECHNICIANS',
#  '49-2022': 'TELECOMMUNICATIONS EQUIPMENT INSTALLERS AND',
#  '15-1113': 'COMPUTER PROGRAMMERS',
#  '41-9091': 'DOOR-TO-DOOR SALES WORKERS, NEWS AND STREET',
#  '29-1161': 'NURSE MIDWIVES',
#  '26-1062': 'FAMILY AND GENERAL PRACTITIONERS',
#  '51-8012': 'POWER DISTRIBUTORS AND DISPATCHERS',
#  '31-9093': 'MEDICAL EQUIPMENT PREPARERS',
#  '51-9012': 'SEPARATING, FILTERING, CLARIFYING, PRECIPITATING,',
#  '47-2061': 'CONSTRUCTION LABORERS',
#  '51-2093': 'TIMING DEVICE ASSEMBLERS AND ADJUSTERS',
#  '51-7011': 'CABINETMAKERS AND BENCH CARPENTERS',
#  '49-9063': 'MUSICAL INSTRUMENT REPAIRERS AND TUNERS',
#  '47-2152': 'PLUMBERS, PIPEFITTERS, AND STEAMFITTERS',
#  '51-9199': 'PRODUCTION WORKERS, ALL OTHER',
#  '43-4171': 'RECEPTIONISTS AND INFORMATION CLERKS',
#  '13-1073': 'TRAINING AND DEVELOPMENT SPECIALISTS',
#  '27-4099': 'MEDIA AND COMMUNICATION EQUIPMENT WORKERS, ALL',
#  '45-2011': 'AGRICULTURAL INSPECTORS',
#  '51-3099': 'FOOD PROCESSING WORKERS, ALL OTHER',
#  '49-9043': 'MAINTENANCE WORKERS, MACHINERY',
#  '23-2092': 'LAW CLERKS',
#  '29-9012': 'OCCUPATIONAL HEALTH AND SAFETY TECHNICIANS',
#  '49-9098': 'HELPERS--INSTALLATION, MAINTENANCE, AND REPAIR',
#  '47-2031': 'CARPENTERS',
#  '43-9031': 'DESKTOP PUBLISHERS',
#  '43-9081': 'PROOFREADERS AND COPY MARKERS',
#  '39-2021': 'NONFARM ANIMAL CARETAKERS',
#  '39-7011': 'TOUR GUIDES AND ESCORTS',
#  '51-6041': 'SHOE AND LEATHER WORKERS AND REPAIRERS',
#  '19-4093': 'FOREST AND CONSERVATION TECHNICIANS',
#  '41-9011': 'DEMONSTRATORS AND PRODUCT PROMOTERS',
#  '51-9151': 'PHOTOGRAPHIC PROCESS WORKERS AND PROCESSING',
#  '31-2011': 'OCCUPATIONAL THERAPY ASSISTANTS',
#  '37-3013': 'TREE TRIMMERS AND PRUNERS',
#  '53-1011': 'AIRCRAFT CARGO HANDLING SUPERVISSORS',
#  '39-6012': 'CONCIERGES',
#  '47-2111': 'ELECTRICIANS',
#  '43-4181': 'RESERVATION AND TRANSPORTATION TICKET AGENTS AND',
#  '41-3098': 'SALES REPRESENTATIVES OF SERVICES, EXCEPT'}

# %%
occupation_count
# Out:
# {'25-1032': 846,
#  '17-2072': 5370,
#  '15-1131': 81165,
#  '15-1132': 88900,
#  '15-2031': 6113,
#  '15-1121': 108276,
#  '15-1199': 53028,
#  '15-1141': 7515,
#  '27-4032': 75,
#  '13-2051': 8199,
#  '17-2081': 388,
#  '27-3031': 1046,
#  '15-2041': 3212,
#  '17-2141': 7350,
#  '15-1142': 9621,
#  '17-2021': 83,
#  '13-2011': 9915,
#  '17-2171': 381,
#  '19-2032': 667,
#  '17-1011': 941,
#  '15-1134': 5123,
#  '13-1161': 6691,
#  '15-1021': 18,
#  '27-1024': 1889,
#  '19-4041': 100,
#  '19-1013': 375,
#  '17-2041': 997,
#  '11-3071': 397,
#  '15-1143': 655,
#  '19-2031': 1764,
#  '21-1015': 105,
#  '25-1021': 474,
#  '11-9199': 718,
#  '17-2071': 5091,
#  '27-1025': 473,
#  '29-1128': 42,
#  '25-1031': 93,
#  '13-2099': 1194,
#  '29-1123': 3474,
#  '11-3021': 4866,
#  '13-1081': 1403,
#  '25-3099': 255,
#  '19-4061': 357,
#  '25-1071': 1361,
#  '25-9031': 486,
#  '15-1133': 15382,
#  '11-1011': 548,
#  '17-2121': 197,
#  '17-2011': 255,
#  '25-2021': 1244,
#  '25-4012': 126,
#  '15-1034': 310,
#  '13-1111': 12065,
#  '11-2021': 2327,
#  '17-2112': 2859,
#  '23-1011': 1250,
#  '29-1069': 4836,
#  '17-2131': 1029,
#  '29-1021': 875,
#  '25-2022': 464,
#  '27-1014': 444,
#  '43-3031': 65,
#  '29-1031': 87,
#  '17-3011': 640,
#  '11-1021': 1504,
#  '11-9013': 201,
#  '13-1051': 585,
#  '17-2199': 2440,
#  '13-2041': 538,
#  '11-9121': 292,
#  '25-1193': 77,
#  '25-1081': 193,
#  '29-1029': 153,
#  '15-1054': 7,
#  '41-3099': 40,
#  '17-2051': 2439,
#  '15-1052': 183,
#  '17-1012': 162,
#  '19-1029': 2576,
#  '19-3011': 765,
#  '29-1061': 79,
#  '19-2011': 72,
#  '19-1042': 3445,
#  '17-3023': 131,
#  '15-1122': 1006,
#  '41-9031': 1854,
#  '29-1171': 92,
#  '29-1062': 863,
#  '11-2031': 199,
#  '19-4021': 932,
#  '11-9041': 1180,
#  '29-1063': 1838,
#  '19-1021': 2738,
#  '17-2061': 995,
#  '25-1125': 107,
#  '19-1022': 391,
#  '29-2011': 756,
#  '15-1111': 1189,
#  '25-1123': 128,
#  '11-3121': 281,
#  '19-3051': 139,
#  '19-2012': 784,
#  '11-3051': 590,
#  '27-3041': 387,
#  '19-4011': 50,
#  '29-1122': 672,
#  '27-1021': 1737,
#  '25-2052': 131,
#  '11-9081': 128,
#  '15-1022': 146,
#  '25-2012': 181,
#  '17-1022': 34,
#  '11-2022': 964,
#  '17-3029': 208,
#  '27-3091': 213,
#  '17-2031': 763,
#  '15-1035': 130,
#  '19-1012': 435,
#  '17-3031': 6,
#  '23-2099': 117,
#  '25-1124': 554,
#  '25-2031': 1351,
#  '29-9091': 60,
#  '25-4021': 74,
#  '13-1151': 447,
#  '11-3031': 1533,
#  '13-1199': 1042,
#  '17-3013': 67,
#  '15-1152': 298,
#  '29-1141': 176,
#  '15-2011': 598,
#  '29-1065': 437,
#  '25-1063': 326,
#  '29-1066': 337,
#  '29-1067': 170,
#  '21-1021': 91,
#  '21-2011': 75,
#  '11-3131': 145,
#  '43-4161': 15,
#  '13-2031': 460,
#  '13-1071': 1081,
#  '11-3011': 129,
#  '29-1199': 657,
#  '13-1141': 136,
#  '27-1011': 372,
#  '11-3061': 351,
#  '15-1151': 800,
#  '15-1037': 36,
#  '25-1022': 666,
#  '29-9011': 67,
#  '15-1799': 119,
#  '19-1011': 119,
#  '25-9099': 36,
#  '25-1121': 273,
#  '53-2012': 6,
#  '19-2042': 370,
#  '27-2012': 261,
#  '25-1072': 59,
#  '27-3042': 278,
#  '11-9021': 448,
#  '15-2099': 41,
#  '25-1052': 216,
#  '11-9033': 252,
#  '29-1131': 295,
#  '21-1011': 25,
#  '25-1011': 816,
#  '15-1053': 36,
#  '27-2022': 312,
#  '29-1051': 999,
#  '19-3094': 58,
#  '25-1042': 249,
#  '21-2021': 51,
#  '19-3031': 91,
#  '25-3021': 57,
#  '21-1022': 42,
#  '27-1022': 417,
#  '17-3022': 47,
#  '11-9111': 639,
#  '21-1014': 121,
#  '11-2011': 386,
#  '41-4011': 184,
#  '13-1121': 231,
#  '19-2021': 122,
#  '29-1064': 90,
#  '29-1127': 417,
#  '29-1071': 42,
#  '25-1054': 172,
#  '51-9071': 6,
#  '25-9041': 8,
#  '19-3099': 87,
#  '29-9099': 550,
#  '49-1011': 6,
#  '29-2012': 15,
#  '25-1041': 81,
#  '13-1041': 645,
#  '19-3091': 12,
#  '19-3041': 57,
#  '41-4012': 69,
#  '25-2053': 108,
#  '37-1011': 1,
#  '27-1019': 17,
#  '15-2021': 281,
#  '25-3011': 69,
#  '17-2074': 145,
#  '11-9151': 191,
#  '19-1041': 93,
#  '41-3031': 308,
#  '19-2099': 154,
#  '25-1122': 135,
#  '21-1091': 154,
#  '17-2053': 85,
#  '27-3099': 150,
#  '31-2021': 20,
#  '17-2144': 190,
#  '25-1066': 148,
#  '19-1099': 249,
#  '13-1022': 82,
#  '27-3043': 187,
#  '17-3012': 9,
#  '15-1032': 7,
#  '17-2161': 40,
#  '19-4099': 78,
#  '43-9111': 62,
#  '29-9092': 12,
#  '17-2076': 34,
#  '19-3092': 56,
#  '41-9012': 56,
#  '17-2073': 13,
#  '19-2043': 66,
#  '25-1082': 22,
#  '25-2011': 144,
#  '13-2052': 192,
#  '15-1031': 14,
#  '45-1011': 21,
#  '49-9044': 2,
#  '21-1012': 220,
#  '25-1111': 32,
#  '15-1099': 62,
#  '25-2054': 149,
#  '13-1131': 33,
#  '25-2041': 43,
#  '17-2111': 144,
#  '35-1011': 110,
#  '17-2075': 5,
#  '23-2011': 213,
#  '19-2041': 273,
#  '25-1061': 42,
#  '29-2091': 21,
#  '25-1199': 158,
#  '31-9099': 19,
#  '19-3039': 77,
#  '17-1021': 52,
#  '25-2059': 50,
#  '13-1011': 47,
#  '29-1081': 32,
#  '17-2052': 12,
#  '11-9032': 89,
#  '15-1150': 26,
#  '19-3022': 84,
#  '17-3027': 55,
#  '25-1053': 40,
#  '25-1065': 109,
#  '25-1043': 10,
#  '17-2151': 108,
#  '29-1041': 80,
#  '41-3011': 29,
#  '25-1113': 37,
#  '15-1051': 70,
#  '51-3092': 1,
#  '25-1051': 67,
#  '29-1022': 16,
#  '43-6011': 14,
#  '43-6014': 21,
#  '13-2061': 68,
#  '15-1036': 49,
#  '11-9161': 10,
#  '43-9041': 2,
#  '43-9199': 21,
#  '43-1011': 16,
#  '39-9041': 20,
#  '13-1023': 180,
#  '15-2091': 29,
#  '25-3999': 5,
#  '15-1311': 4,
#  '23-1012': 195,
#  '25-1126': 142,
#  '21-1099': 41,
#  '27-3022': 255,
#  '27-1027': 35,
#  '53-2011': 3,
#  '41-3021': 18,
#  '19-3032': 41,
#  '15-1023': 25,
#  '21-1023': 46,
#  '19-1031': 13,
#  '43-4051': 22,
#  '45-2021': 14,
#  '29-2052': 32,
#  '29-2031': 5,
#  '13-2071': 59,
#  '29-1111': 25,
#  '13-2053': 68,
#  '51-4032': 2,
#  '29-2099': 23,
#  '17-2143': 16,
#  '53-6051': 18,
#  '33-9021': 3,
#  '21-1019': 17,
#  '25-1067': 66,
#  '19-4031': 75,
#  '25-9021': 25,
#  '25-1062': 65,
#  '11-9141': 63,
#  '25-1112': 17,
#  '29-1129': 14,
#  '17-3021': 20,
#  '11-9031': 40,
#  '15-1331': 1,
#  '51-7041': 2,
#  '51-4121': 3,
#  '43-5061': 18,
#  '47-4011': 9,
#  '47-2141': 2,
#  '51-1011': 13,
#  '25-9011': 7,
#  '51-9122': 1,
#  '41-1012': 12,
#  '33-9099': 1,
#  '21-1029': 30,
#  '11-9051': 159,
#  '27-1029': 194,
#  '31-9092': 4,
#  '29-1181': 23,
#  '25-1192': 21,
#  '27-2099': 8,
#  '15-1191': 1,
#  '31-9096': 6,
#  '25-4013': 50,
#  '17-3026': 11,
#  '39-9099': 1,
#  '31-2022': 1,
#  '21-1013': 14,
#  '25-1194': 35,
#  '11-9039': 58,
#  '39-9031': 17,
#  '19-1023': 56,
#  '39-9032': 88,
#  '29-1023': 16,
#  '29-2092': 1,
#  '19-4091': 27,
#  '31-1014': 1,
#  '25-1069': 39,
#  '11-1531': 1,
#  '19-3093': 6,
#  '29-9199': 1,
#  '27-3021': 15,
#  '39-3032': 1,
#  '25-2051': 33,
#  '29-2032': 5,
#  '49-9021': 2,
#  '25-1064': 46,
#  '39-9011': 2,
#  '49-9064': 2,
#  '47-4099': 5,
#  '27-2041': 59,
#  '11-3111': 18,
#  '29-1011': 52,
#  '15-1061': 4,
#  '21-1093': 18,
#  '49-2094': 3,
#  '15-1055': 4,
#  '29-9799': 3,
#  '13-1031': 12,
#  '21-1094': 13,
#  '29-2034': 5,
#  '43-3021': 3,
#  '15-1071': 6,
#  '29-1024': 13,
#  '29-2041': 1,
#  '45-2092': 2,
#  '41-9022': 4,
#  '53-6099': 1,
#  '21-1798': 1,
#  '39-7012': 3,
#  '29-2071': 8,
#  '27-4011': 8,
#  '13-2072': 31,
#  '41-1011': 13,
#  '51-9081': 12,
#  '27-2042': 16,
#  '29-1125': 24,
#  '49-2095': 1,
#  '29-1126': 3,
#  '39-2011': 5,
#  '25-4011': 28,
#  '41-9041': 1,
#  '41-9099': 9,
#  '13-1021': 16,
#  '17-3019': 5,
#  '23-1022': 5,
#  '13-2082': 25,
#  '43-9011': 3,
#  '35-1012': 10,
#  '53-5021': 6,
#  '43-5071': 2,
#  '21-1092': 2,
#  '47-2211': 1,
#  '33-3021': 5,
#  '17-3024': 9,
#  '53-1031': 2,
#  '13-2021': 13,
#  '47-2073': 4,
#  '41-3041': 4,
#  '17-3025': 16,
#  '25-9030': 1,
#  '19-1032': 3,
#  '45-2093': 2,
#  '27-3011': 1,
#  '29-2056': 5,
#  '19-4092': 6,
#  '27-1013': 9,
#  '15-1011': 2,
#  '19-3021': 6,
#  '25-2025': 1,
#  '43-3011': 1,
#  '35-9099': 1,
#  '51-3011': 1,
#  '27-4021': 13,
#  '25-2023': 1,
#  '37-1012': 3,
#  '31-9095': 3,
#  '14-2051': 1,
#  '43-4011': 3,
#  '39-3031': 1,
#  '27-2014': 1,
#  '26-1067': 1,
#  '23-2093': 1,
#  '47-1011': 7,
#  '41-2011': 1,
#  '43-4041': 1,
#  '25-2032': 4,
#  '51-6099': 1,
#  '13-1078': 5,
#  '51-5112': 2,
#  '15-2013': 2,
#  '49-3023': 7,
#  '43-5032': 1,
#  '53-6041': 5,
#  '51-6052': 2,
#  '49-9062': 1,
#  '21-2099': 8,
#  '29-1151': 5,
#  '43-3099': 9,
#  '15-1179': 7,
#  '13-2081': 2,
#  '27-4031': 6,
#  '43-3061': 3,
#  '43-5011': 6,
#  '13-1075': 10,
#  '43-4081': 4,
#  '31-1012': 2,
#  '41-9021': 1,
#  '17-2016': 1,
#  '43-6012': 5,
#  '51-9061': 2,
#  '31-9091': 4,
#  '17-2062': 1,
#  '51-2023': 2,
#  '27-4014': 7,
#  '27-2032': 3,
#  '41-2031': 4,
#  '39-3091': 2,
#  '37-2012': 1,
#  '35-2014': 2,
#  '27-2011': 1,
#  '43-3051': 2,
#  '49-3011': 6,
#  '13-1611': 1,
#  '35-3041': 2,
#  '43-9061': 4,
#  '43-4151': 1,
#  '19-4051': 1,
#  '51-4122': 1,
#  '29-1124': 2,
#  '39-1011': 1,
#  '45-2099': 1,
#  '25-1191': 2,
#  '51-4012': 2,
#  '29-2799': 2,
#  '51-6092': 1,
#  '31-1011': 1,
#  '25-3098': 1,
#  '19-1069': 1,
#  '27-4012': 1,
#  '49-2022': 1,
#  '15-1113': 1,
#  '41-9091': 1,
#  '29-1161': 1,
#  '26-1062': 1,
#  '51-8012': 1,
#  '31-9093': 1,
#  '51-9012': 2,
#  '47-2061': 1,
#  '51-2093': 1,
#  '51-7011': 1,
#  '49-9063': 2,
#  '47-2152': 1,
#  '51-9199': 6,
#  '43-4171': 1,
#  '13-1073': 2,
#  '27-4099': 3,
#  '45-2011': 42,
#  '51-3099': 2,
#  '49-9043': 1,
#  '23-2092': 1,
#  '29-9012': 1,
#  '49-9098': 1,
#  '47-2031': 1,
#  '43-9031': 1,
#  '43-9081': 3,
#  '39-2021': 1,
#  '39-7011': 1,
#  '51-6041': 1,
#  '19-4093': 5,
#  '41-9011': 1,
#  '51-9151': 1,
#  '31-2011': 1,
#  '37-3013': 1,
#  '53-1011': 1,
#  '39-6012': 1,
#  '47-2111': 1,
#  '43-4181': 1,
#  '41-3098': 1}

# %%
print(len(state_count))
state_count
# Out:
# 55
# {'OK': 940,
#  'TX': 84626,
#  'VA': 18338,
#  'CA': 86066,
#  'NJ': 79950,
#  'WI': 3398,
#  'NY': 37508,
#  'MI': 19792,
#  'IL': 33119,
#  'NC': 17456,
#  'CT': 5257,
#  'DE': 2080,
#  'WA': 12568,
#  'MD': 23115,
#  'PA': 23437,
#  'MN': 3647,
#  'IA': 1600,
#  'KS': 1628,
#  'CO': 3100,
#  'AR': 1565,
#  'MA': 17622,
#  'FL': 15519,
#  'OH': 8259,
#  'LA': 1488,
#  'NV': 823,
#  'MS': 432,
#  'MO': 3763,
#  'GA': 15023,
#  'SC': 982,
#  'MP': 52,
#  'RI': 961,
#  'IN': 2536,
#  'NM': 703,
#  'SD': 225,
#  'AZ': 3019,
#  'DC': 1958,
#  'TN': 3195,
#  'ID': 425,
#  'OR': 1607,
#  'AL': 1221,
#  'UT': 1262,
#  'KY': 1893,
#  'HI': 329,
#  'GU': 423,
#  'NE': 1128,
#  'ME': 439,
#  'ND': 357,
#  'AK': 89,
#  'NH': 1074,
#  'WV': 274,
#  'PR': 121,
#  'VT': 587,
#  'VI': 67,
#  'MT': 81,
#  'WY': 125}

# %%
certified_count
# Out:
# 547252

# %%
def ratio_formatted(job_count, total):
    num = round(100 * float(job_count) / total, 1)
    return str(num) + '%'

def occupation_analysis(count, names, total):
    sorted_occupations = sorted(count.items(), key=lambda kv: kv[1])
    sorted_occupations.reverse()
    top_ten = sorted_occupations[:10]
    
    occupation_answer = ['TOP_OCCUPATIONS;NUMBER_CERTIFIED_APPLICATIONS;PERCENTAGE']
    for job in top_ten:
        row = []
        row.append(names[job[0]])
        row.append(str(job[1]))
        row.append(ratio_formatted(job[1], total))
        occupation_answer.append(';'.join(row))
    return "\n".join(occupation_answer)

# %%
print(occupation_analysis(occupation_count, occupation_dict, certified_count))
# Out:
# TOP_OCCUPATIONS;NUMBER_CERTIFIED_APPLICATIONS;PERCENTAGE
# COMPUTER SOFTWARE ENGINEERS, APPLICATIONS;108276;19.8%
# COMPUTER SOFTWARE ENGINEERS, APPLICATIONS;88900;16.2%
# SOFTWARE DEVELOPERS, APPLICATIONS;81165;14.8%
# COMPUTER OCCUPATIONS, ALL OTHER: INFORMATION TECHN;53028;9.7%
# SOFTWARE DEVELOPPERS, SYSTEMS SOFTWARE;15382;2.8%
# MANAGEMENT ANALYSTS;12065;2.2%
# OPERATIONS RESEARCH ANALYSTS;9915;1.8%
# NETWORK AND COMPUTER SYSTEMS ADMINISTRATORS*;9621;1.8%
# FINANCIAL ANALYSTS;8199;1.5%
# DATABASE ADMINISTRATORS;7515;1.4%

# %%
def state_analysis(count, total):
    sorted_states = sorted(count.items(), key=lambda kv: kv[1])
    sorted_states.reverse()
    top_ten = sorted_states[:10]
    
    states_answer = ['TOP_STATES;NUMBER_CERTIFIED_APPLICATIONS;PERCENTAGE']
    for state in top_ten:
        row = []
        row.append(state[0])
        row.append(str(state[1]))
        row.append(ratio_formatted(state[1], total))
        states_answer.append(';'.join(row))
    return "\n".join(states_answer)

# %%
print(state_analysis(state_count, certified_count))
# Out:
# TOP_STATES;NUMBER_CERTIFIED_APPLICATIONS;PERCENTAGE
# CA;86066;15.7%
# TX;84626;15.5%
# NJ;79950;14.6%
# NY;37508;6.9%
# IL;33119;6.1%
# PA;23437;4.3%
# MD;23115;4.2%
# MI;19792;3.6%
# VA;18338;3.4%
# MA;17622;3.2%
